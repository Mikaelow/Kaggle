# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikaelow/Kaggle/blob/main/car_predicting_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# uploading dataset
db_source = '/content/cars_formated.csv'
# puting data base to the
cars_formated = pd.read_csv(db_source, index_col = 'Unnamed: 0')

# %%
cars_formated
# Out:
#        year   make                model         body transmission  \
# 0      2015    kia              sorento          suv    automatic
# 1      2015    kia              sorento          suv    automatic
# 2      2014    bmw             3 series        sedan    automatic
# 3      2015  volvo                  s60        sedan    automatic
# 4      2014    bmw  6 series gran coupe        sedan    automatic
# ...     ...    ...                  ...          ...          ...
# 40066  2014   ford              mustang        coupe    automatic
# 40067  2014   ford              mustang  convertible    automatic
# 40069  2014   ford                focus        sedan    automatic
# 40070  2014   ford               taurus        sedan    automatic
# 40071  2014   ford              mustang  convertible    automatic
#
#                      vin  condition  odometer   color  sellingprice
# 0      5xyktca69fg566472        5.0   16639.0   white       21500.0
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikaelow/Kaggle/blob/main/car_predicting_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random

# %%
# uploading dataset
db_source = 'cars_formated.csv'
# puting data base to the, I only choose 50k rows to get faster comilation
cars_formated = pd.read_csv(db_source, index_col = 'Unnamed: 0').sample(50000,random_state=1)

# %%
cars_formated
# Out:
#         year       make          model           body transmission  \
# 234624  2014      dodge        journey            suv    automatic
# 99107   2011     toyota     highlander            suv    automatic
# 252966  2007     toyota          camry          sedan    automatic
# 383114  2012     nissan     pathfinder            suv    automatic
# 159656  2013     nissan         altima          sedan    automatic
# ...      ...        ...            ...            ...          ...
# 352441  2012     toyota     highlander            suv    automatic
# 426376  2013    hyundai  genesis coupe  genesis coupe    automatic
# 510213  2008      buick        enclave            suv    automatic
# 385790  2014     nissan          versa          sedan    automatic
# 153707  2010  chevrolet          tahoe            suv    automatic
#
#                       vin  condition  odometer   color  sellingprice
# 234624  3c4pdcbb3et180538        4.0   20366.0     red       15700.0
# ...

# %%
# choosing most value columns from the data base
columns_choosen = cars_formated.columns
columns_choosen = columns_choosen.drop('vin')

# %%
cars_formated.dtypes
# Out:
# year              int64
# make             object
# model            object
# body             object
# transmission     object
# vin              object
# condition       float64
# odometer        float64
# color            object
# sellingprice    float64
# dtype: object

# %%
# encoding from object to bool
one_hot_encoded_db = pd.get_dummies(cars_formated[columns_choosen])

one_hot_encoded_db
# Out:
#         year  condition  odometer  sellingprice  make_acura  \
# 234624  2014        4.0   20366.0       15700.0       False
# 99107   2011       36.0   97494.0       21500.0       False
# 252966  2007       37.0   93568.0        9200.0       False
# 383114  2012       29.0   54826.0       15900.0       False
# 159656  2013        4.0   60131.0       12400.0       False
# ...      ...        ...       ...           ...         ...
# 352441  2012       41.0   31666.0       30800.0       False
# 426376  2013        4.0   25726.0       21000.0       False
# 510213  2008       42.0  112777.0       11700.0       False
# 385790  2014       43.0   37363.0       10000.0       False
# 153707  2010       45.0   99681.0       24500.0       False
#
#         make_aston martin  make_audi  make_bentley  make_bmw  make_buick  ...  \
# 234624              False      False         False     False       False  ...
# 99107               False      False         False     False       False  ...
# ...

# %% [markdown]
# # Spliting data to features and labels

# %%
features = one_hot_encoded_db.columns
# spliting to feature data base
# X = cars_formated[features]
features = features.drop('sellingprice')
features
# Out:
# Index(['year', 'condition', 'odometer', 'make_acura', 'make_aston martin',
#        'make_audi', 'make_bentley', 'make_bmw', 'make_buick', 'make_cadillac',
#        ...
#        'color_lime', 'color_off-white', 'color_orange', 'color_pink',
#        'color_purple', 'color_red', 'color_silver', 'color_turquoise',
#        'color_white', 'color_yellow'],
#       dtype='object', length=767)

# %%
# spliting to label
X = one_hot_encoded_db[features]
y = one_hot_encoded_db['sellingprice']
X
# Out:
#         year  condition  odometer  make_acura  make_aston martin  make_audi  \
# 234624  2014        4.0   20366.0       False              False      False
# 99107   2011       36.0   97494.0       False              False      False
# 252966  2007       37.0   93568.0       False              False      False
# 383114  2012       29.0   54826.0       False              False      False
# 159656  2013        4.0   60131.0       False              False      False
# ...      ...        ...       ...         ...                ...        ...
# 352441  2012       41.0   31666.0       False              False      False
# 426376  2013        4.0   25726.0       False              False      False
# 510213  2008       42.0  112777.0       False              False      False
# 385790  2014       43.0   37363.0       False              False      False
# 153707  2010       45.0   99681.0       False              False      False
#
# ...

# %% [markdown]
# # Building first model

# %%
# importing models
from sklearn.tree import DecisionTreeRegressor
# import mae
from sklearn.metrics import mean_absolute_error
# import db split to validate data
from sklearn.model_selection import train_test_split

# %%
# define model. Specify a number for random_state to ensure same results each run
car_model = DecisionTreeRegressor(random_state=1)

# fit model
car_model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
# predicting price
pred_car_price = car_model.predict(X)
# checking mae
mae_pred = mean_absolute_error(y,pred_car_price)
mae_pred
# Out:
# 0.0

# %%
# % of the mean
mae_pred_proc = (mae_pred/y.mean())*100
mae_pred_proc
# Out:
# 0.0

# %% [markdown]
# **Observation: MAE is very low, only `0.309`, it represents just `0.002%` of the average car price.**

# %% [markdown]
# # Validating model

# %%
# building new model

# spliting data to train and validation
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# define new car model
car_model_with_validation = DecisionTreeRegressor(random_state = 1)
# fiting model
car_model_with_validation.fit(train_X, train_y)
# predicting price
pred_car_price_with_validation = car_model_with_validation.predict(val_X)

# %%
# checking mae
mae_pred_with_validation = mean_absolute_error(val_y, pred_car_price_with_validation)
mae_pred_with_validation
# Out:
# 2491.61416

# %%
# % of the mean
mae_pred_with_validation_proc = (mae_pred_with_validation/y.mean())*100
mae_pred_with_validation_proc
# Out:
# 18.200694691059923

# %% [markdown]
# **Observation: MAE is much bigger than without validation `2003.38`, it represents just `14.66%` of the average car price.**

# %% [markdown]
# # Underfitting and Overfitting

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state = 1)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  4904
# Max leaf nodes: 50  		 Mean Absolute Error:  3797
# Max leaf nodes: 500  		 Mean Absolute Error:  2734
# Max leaf nodes: 5000  		 Mean Absolute Error:  2287

# %%
my_mae_proc = (my_mae  /y.mean())*100
my_mae_proc
# Out:
# 16.71292570389179

# %% [markdown]
# **Observation: From the `max_leaf_nodes = [5, 50, 500, 5000]`, the best MAE occurs when `max_leaf_nodes` is equal to `5000`, with a value of `1750`, representing just `12.82%`.**

# %% [markdown]
# # Creating random forest

# %%
# importing random forest
from sklearn.ensemble import RandomForestRegressor

# define random model
forest_model = RandomForestRegressor(random_state=1)
# fiting model
forest_model.fit(train_X, train_y)
# predicting
car_price_forest_pred = forest_model.predict(val_X)
# compare car_price_forest_pred with val_y in mae
mae_random_forest = mean_absolute_error(val_y, car_price_forest_pred)

# %%
mae_random_forest_proc = (mae_random_forest/y.mean())*100
mae_random_forest_proc
# Out:
# 13.725820841040933

# %% [markdown]
# **Observation: RandomForestRegressor have the best from previous method MAE equal `1515`,representing just `11.1%`.**

# %% [markdown]
# # Create Linear Regression

# %%
# importing Linear Regression
from sklearn.linear_model import LinearRegression

# creating Linear Regression model
linear_regression_model = LinearRegression()

# fiting model
linear_regression_model.fit(train_X, train_y)

# predicting price
pred_price_linear_regression = linear_regression_model.predict(val_X)

# compare car_price_forest_pred with val_y in mae
mae_linear_regression = mean_absolute_error(val_y, pred_price_linear_regression)
mae_linear_regression
# Out:
# 2709.3145231385793

# %%
mae_linear_regression_proc = (mae_linear_regression/y.mean())*100
mae_linear_regression_proc
# Out:
# 19.790948072674254

# %% [markdown]
# # Create SVM

# %%
# importing SVM
from sklearn import svm

# creating model
svm_model = svm.SVC()

# fiting model
svm_model.fit(train_X, train_y)

# predicting price
pred_price_svm = svm_model.predict(val_X)

#compare pred_price_svm with val_y in mae
mae_svm = mean_absolute_error(val_y, pred_price_svm)
mae_svm
# Out:
# 5785.52472

# %%
mae_SVM_proc = (mae_svm/y.mean())*100
mae_SVM_proc
# Out:
# 42.26198853208474

# %%
comparision_table = pd.DataFrame([
    ['MAE', mae_pred, mae_pred_with_validation, my_mae,mae_random_forest,mae_linear_regression,mae_svm],
    ['MAE of mean %', mae_pred, mae_pred_with_validation_proc, my_mae_proc, mae_random_forest_proc, mae_linear_regression_proc,mae_SVM_proc]
], columns = ['','Full fill','Validadion','5000 leaf','Random Forest','Linear Regression','SVM'])
comparision_table.round(2)
# Out:
#                   Full fill  Validadion  5000 leaf  Random Forest  \
# 0            MAE        0.0     2491.61    2287.94        1879.02
# 1  MAE of mean %        0.0       18.20      16.71          13.73
#
#    Linear Regression      SVM
# 0            2709.31  5785.52
# 1              19.79    42.26

# %%
# choosing most value columns from the data base
columns_choosen = cars_formated.columns
columns_choosen = columns_choosen.drop('vin')

# %%
cars_formated.dtypes
# Out:
# year              int64
# make             object
# model            object
# body             object
# transmission     object
# vin              object
# condition       float64
# odometer        float64
# color            object
# sellingprice    float64
# dtype: object

# %%
# encoding from object to bool
one_hot_encoded_db = pd.get_dummies(cars_formated[columns_choosen])

one_hot_encoded_db
# Out:
#        year  condition  odometer  sellingprice  make_acura  make_audi  \
# 0      2015        5.0   16639.0       21500.0       False      False
# 1      2015        5.0    9393.0       21500.0       False      False
# 2      2014       45.0    1331.0       30000.0       False      False
# 3      2015       41.0   14282.0       27750.0       False      False
# 4      2014       43.0    2641.0       67000.0       False      False
# ...     ...        ...       ...           ...         ...        ...
# 40066  2014       49.0   20285.0       24000.0       False      False
# 40067  2014       48.0   18035.0       30100.0       False      False
# 40069  2014       41.0   24382.0       13600.0       False      False
# 40070  2014       43.0   18239.0       22500.0       False      False
# 40071  2014       48.0    6448.0       26000.0       False      False
#
#        make_bentley  make_bmw  make_buick  make_cadillac  ...  color_lime  \
# ...

# %% [markdown]
# # Spliting data to features and labels

# %%
features = one_hot_encoded_db.columns
# spliting to feature data base
# X = cars_formated[features]
features = features.drop('sellingprice')
features
# Out:
# Index(['year', 'condition', 'odometer', 'make_acura', 'make_audi',
#        'make_bentley', 'make_bmw', 'make_buick', 'make_cadillac',
#        'make_chevrolet',
#        ...
#        'color_lime', 'color_off-white', 'color_orange', 'color_pink',
#        'color_purple', 'color_red', 'color_silver', 'color_turquoise',
#        'color_white', 'color_yellow'],
#       dtype='object', length=740)

# %%
X[X.isna()]
# Out:
#        year  condition  odometer make_acura make_aston martin make_audi  \
# 0       NaN        NaN       NaN        NaN               NaN       NaN
# 1       NaN        NaN       NaN        NaN               NaN       NaN
# 2       NaN        NaN       NaN        NaN               NaN       NaN
# 3       NaN        NaN       NaN        NaN               NaN       NaN
# 4       NaN        NaN       NaN        NaN               NaN       NaN
# ...     ...        ...       ...        ...               ...       ...
# 76641   NaN        NaN       NaN        NaN               NaN       NaN
# 76642   NaN        NaN       NaN        NaN               NaN       NaN
# 76643   NaN        NaN       NaN        NaN               NaN       NaN
# 76644   NaN        NaN       NaN        NaN               NaN       NaN
# 76645   NaN        NaN       NaN        NaN               NaN       NaN
#
#       make_bentley make_bmw make_buick make_cadillac  ... color_lime  \
# ...

# %%
# spliting to label
X = one_hot_encoded_db[features]
y = one_hot_encoded_db['sellingprice']
X
# Out:
#        year  condition  odometer  make_acura  make_audi  make_bentley  \
# 0      2015        5.0   16639.0       False      False         False
# 1      2015        5.0    9393.0       False      False         False
# 2      2014       45.0    1331.0       False      False         False
# 3      2015       41.0   14282.0       False      False         False
# 4      2014       43.0    2641.0       False      False         False
# ...     ...        ...       ...         ...        ...           ...
# 40066  2014       49.0   20285.0       False      False         False
# 40067  2014       48.0   18035.0       False      False         False
# 40069  2014       41.0   24382.0       False      False         False
# 40070  2014       43.0   18239.0       False      False         False
# 40071  2014       48.0    6448.0       False      False         False
#
#        make_bmw  make_buick  make_cadillac  make_chevrolet  ...  color_lime  \
# ...

# %% [markdown]
# # Building first model

# %%
# importing models
from sklearn.tree import DecisionTreeRegressor
# import mae
from sklearn.metrics import mean_absolute_error
# import db split to validate data
from sklearn.model_selection import train_test_split

# %%
# define model. Specify a number for random_state to ensure same results each run
car_model = DecisionTreeRegressor(random_state=1)

# fit model
car_model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
# predicting price
pred_car_price = car_model.predict(X)
# checking mae
mae_pred = mean_absolute_error(y,pred_car_price)
mae_pred
# Out:
# 0.11994329953113074

# %%
# % of the mean
mae_pred_proc = (mae_pred/y.mean())*100
mae_pred_proc
# Out:
# 0.0008922142271896674

# %% [markdown]
# **Observation: MAE is very low, only `0.309`, it represents just `0.002%` of the average car price.**

# %% [markdown]
# # Validating model

# %%
# building new model

# spliting data to train and validation
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# define new car model
car_model_with_validation = DecisionTreeRegressor(random_state = 1)
# fiting model
car_model_with_validation.fit(train_X, train_y)
# predicting price
pred_car_price_with_validation = car_model_with_validation.predict(val_X)

# %%
# checking mae
mae_pred_with_validation = mean_absolute_error(val_y, pred_car_price_with_validation)
mae_pred_with_validation
# Out:
# 2853.438290449193

# %%
# % of the mean
mae_pred_with_validation_proc = (mae_pred_with_validation/y.mean())*100
mae_pred_with_validation_proc
# Out:
# 21.225681210193496

# %% [markdown]
# **Observation: MAE is much bigger than without validation `2003.38`, it represents just `14.66%` of the average car price.**

# %% [markdown]
# # Underfitting and Overfitting

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state = 1)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  5217
# Max leaf nodes: 50  		 Mean Absolute Error:  3978
# Max leaf nodes: 500  		 Mean Absolute Error:  2957
# Max leaf nodes: 5000  		 Mean Absolute Error:  2768

# %%
my_mae_proc = (my_mae  /y.mean())*100
my_mae_proc
# Out:
# 20.59522504329244

# %% [markdown]
# **Observation: From the `max_leaf_nodes = [5, 50, 500, 5000]`, the best MAE occurs when `max_leaf_nodes` is equal to `5000`, with a value of `1750`, representing just `12.82%`.**

# %% [markdown]
# # Creating random forest

# %%
# importing random forest
from sklearn.ensemble import RandomForestRegressor

# define random model
forest_model = RandomForestRegressor(random_state=1)
# fiting model
forest_model.fit(train_X, train_y)
# predicting
car_price_forest_pred = forest_model.predict(val_X)
# compare car_price_forest_pred with val_y in mae
mae_random_forest = mean_absolute_error(val_y, car_price_forest_pred)

# %%
mae_random_forest_proc = (mae_random_forest/y.mean())*100
mae_random_forest_proc
# Out:
# 16.212067525190758

# %% [markdown]
# **Observation: RandomForestRegressor have the best from previous method MAE equal `1515`,representing just `11.1%`.**

# %% [markdown]
# # Create Linear Regression

# %%
# importing Linear Regression
from sklearn.linear_model import LinearRegression

# creating Linear Regression model
linear_regression_model = LinearRegression()

# fiting model
linear_regression_model.fit(train_X, train_y)

# predicting price
pred_price_linear_regression = linear_regression_model.predict(val_X)

# compare car_price_forest_pred with val_y in mae
mae_linear_regression = mean_absolute_error(val_y, pred_price_linear_regression)
mae_linear_regression
# Out:
# 2901.8560733869454

# %%
mae_linear_regression_proc = (mae_linear_regression/y.mean())*100
mae_linear_regression_proc
# Out:
# 21.585843344759688

# %% [markdown]
# # Create SVM

# %%
# importing SVM
from sklearn import svm

# creating model
svm_model = svm.SVC()

# fiting model
svm_model.fit(train_X, train_y)

# predicting price
pred_price_svm = svm_model.predict(val_X)

#compare pred_price_svm with val_y in mae
mae_svm = mean_absolute_error(val_y, pred_price_svm)
mae_svm

# %%
mae_SVM_proc = (mae_svm/y.mean())*100
mae_SVM_proc

# %%
comparision_table = pd.DataFrame([
    ['MAE', mae_pred, mae_pred_with_validation, my_mae,mae_random_forest,mae_linear_regression,mae_svm],
    ['MAE of mean %', mae_pred, mae_pred_with_validation_proc, my_mae_proc, mae_random_forest_proc, mae_linear_regression_proc,mae_SVM_proc]
], columns = ['','Full fill','Validadion','5000 leaf','Random Forest','Linear Regression','SVM'])
comparision_table.round(2)
# Out:
#                   Full fill  Validadion  5000 leaf  Random Forest  \
# 0            MAE       0.12     2853.44    2768.68        2179.44
# 1  MAE of mean %       0.12       21.23      20.60          16.21
#
#    Linear Regression
# 0            2901.86
# 1              21.59
