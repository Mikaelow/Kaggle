# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cars-formated/cars_formated.csv

# %%
# uploading dataset
db_source = '/kaggle/input/cars-formated/cars_formated.csv'
# puting data base to the 
cars_formated = pd.read_csv(db_source, index_col = 'Unnamed: 0')

# %%
cars_formated
# Out:
#         year    make                model       body transmission  \
# 0       2015     kia              sorento        suv    automatic
# 1       2015     kia              sorento        suv    automatic
# 2       2014     bmw             3 series      sedan    automatic
# 3       2015   volvo                  s60      sedan    automatic
# 4       2014     bmw  6 series gran coupe      sedan    automatic
# ...      ...     ...                  ...        ...          ...
# 558832  2015     kia                 k900      sedan    automatic
# 558833  2012     ram                 2500   crew cab    automatic
# 558834  2012     bmw                   x5        suv    automatic
# 558835  2015  nissan               altima      sedan    automatic
# 558836  2014    ford                f-150  supercrew    automatic
#
#                       vin  condition  odometer   color  sellingprice
# 0       5xyktca69fg566472        5.0   16639.0   white       21500.0
# 1       5xyktca69fg561319        5.0    9393.0   white       21500.0
# 2       wba3c1c51ek116351       45.0    1331.0    gray       30000.0
# 3       yv1612tb4f1310987       41.0   14282.0   white       27750.0
# 4       wba6b2c57ed129731       43.0    2641.0    gray       67000.0
# ...                   ...        ...       ...     ...           ...
# 558832  knalw4d4xf6019304       45.0   18255.0  silver       33000.0
# 558833  3c6td5et6cg112407        5.0   54393.0   white       30800.0
# 558834  5uxzw0c58cl668465       48.0   50561.0   black       34000.0
# 558835  1n4al3ap0fc216050       38.0   16658.0   white       11100.0
# 558836  1ftfw1et2eke87277       34.0   15008.0    gray       26700.0
#
# [510005 rows x 10 columns]

# %%
# choosing most value columns from the data base
columns_choosen = cars_formated.columns
columns_choosen = columns_choosen.drop('vin')

# %%
cars_formated.dtypes
# Out:
# year              int64
# make             object
# model            object
# body             object
# transmission     object
# vin              object
# condition       float64
# odometer        float64
# color            object
# sellingprice    float64
# dtype: object

# %%
# encoding from object to bool
one_hot_encoded_db = pd.get_dummies(cars_formated[columns_choosen])

one_hot_encoded_db
# Out:
#         year  condition  odometer  sellingprice  make_acura  \
# 0       2015        5.0   16639.0       21500.0       False
# 1       2015        5.0    9393.0       21500.0       False
# 2       2014       45.0    1331.0       30000.0       False
# 3       2015       41.0   14282.0       27750.0       False
# 4       2014       43.0    2641.0       67000.0       False
# ...      ...        ...       ...           ...         ...
# 558832  2015       45.0   18255.0       33000.0       False
# 558833  2012        5.0   54393.0       30800.0       False
# 558834  2012       48.0   50561.0       34000.0       False
# 558835  2015       38.0   16658.0       11100.0       False
# 558836  2014       34.0   15008.0       26700.0       False
#
#         make_aston martin  make_audi  make_bentley  make_bmw  make_buick  ...  \
# 0                   False      False         False     False       False  ...
# 1                   False      False         False     False       False  ...
# 2                   False      False         False      True       False  ...
# 3                   False      False         False     False       False  ...
# 4                   False      False         False      True       False  ...
# ...                   ...        ...           ...       ...         ...  ...
# 558832              False      False         False     False       False  ...
# 558833              False      False         False     False       False  ...
# 558834              False      False         False      True       False  ...
# 558835              False      False         False     False       False  ...
# 558836              False      False         False     False       False  ...
#
#         color_lime  color_off-white  color_orange  color_pink  color_purple  \
# 0            False            False         False       False         False
# 1            False            False         False       False         False
# 2            False            False         False       False         False
# 3            False            False         False       False         False
# 4            False            False         False       False         False
# ...            ...              ...           ...         ...           ...
# 558832       False            False         False       False         False
# 558833       False            False         False       False         False
# 558834       False            False         False       False         False
# 558835       False            False         False       False         False
# 558836       False            False         False       False         False
#
#         color_red  color_silver  color_turquoise  color_white  color_yellow
# 0           False         False            False         True         False
# 1           False         False            False         True         False
# 2           False         False            False        False         False
# 3           False         False            False         True         False
# 4           False         False            False        False         False
# ...           ...           ...              ...          ...           ...
# 558832      False          True            False        False         False
# 558833      False         False            False         True         False
# 558834      False         False            False        False         False
# 558835      False         False            False         True         False
# 558836      False         False            False        False         False
#
# [510005 rows x 893 columns]

# %% [markdown]
# # Spliting data to features and labels

# %%
features = one_hot_encoded_db.columns
# spliting to feature data base
# X = cars_formated[features]
features = features.drop('sellingprice')
features
# Out:
# Index(['year', 'condition', 'odometer', 'make_acura', 'make_aston martin',
#        'make_audi', 'make_bentley', 'make_bmw', 'make_buick', 'make_cadillac',
#        ...
#        'color_lime', 'color_off-white', 'color_orange', 'color_pink',
#        'color_purple', 'color_red', 'color_silver', 'color_turquoise',
#        'color_white', 'color_yellow'],
#       dtype='object', length=892)

# %%
# spliting to label
X = one_hot_encoded_db[features]
y = one_hot_encoded_db['sellingprice']
X
# Out:
#         year  condition  odometer  make_acura  make_aston martin  make_audi  \
# 0       2015        5.0   16639.0       False              False      False
# 1       2015        5.0    9393.0       False              False      False
# 2       2014       45.0    1331.0       False              False      False
# 3       2015       41.0   14282.0       False              False      False
# 4       2014       43.0    2641.0       False              False      False
# ...      ...        ...       ...         ...                ...        ...
# 558832  2015       45.0   18255.0       False              False      False
# 558833  2012        5.0   54393.0       False              False      False
# 558834  2012       48.0   50561.0       False              False      False
# 558835  2015       38.0   16658.0       False              False      False
# 558836  2014       34.0   15008.0       False              False      False
#
#         make_bentley  make_bmw  make_buick  make_cadillac  ...  color_lime  \
# 0              False     False       False          False  ...       False
# 1              False     False       False          False  ...       False
# 2              False      True       False          False  ...       False
# 3              False     False       False          False  ...       False
# 4              False      True       False          False  ...       False
# ...              ...       ...         ...            ...  ...         ...
# 558832         False     False       False          False  ...       False
# 558833         False     False       False          False  ...       False
# 558834         False      True       False          False  ...       False
# 558835         False     False       False          False  ...       False
# 558836         False     False       False          False  ...       False
#
#         color_off-white  color_orange  color_pink  color_purple  color_red  \
# 0                 False         False       False         False      False
# 1                 False         False       False         False      False
# 2                 False         False       False         False      False
# 3                 False         False       False         False      False
# 4                 False         False       False         False      False
# ...                 ...           ...         ...           ...        ...
# 558832            False         False       False         False      False
# 558833            False         False       False         False      False
# 558834            False         False       False         False      False
# 558835            False         False       False         False      False
# 558836            False         False       False         False      False
#
#         color_silver  color_turquoise  color_white  color_yellow
# 0              False            False         True         False
# 1              False            False         True         False
# 2              False            False        False         False
# 3              False            False         True         False
# 4              False            False        False         False
# ...              ...              ...          ...           ...
# 558832          True            False        False         False
# 558833         False            False         True         False
# 558834         False            False        False         False
# 558835         False            False         True         False
# 558836         False            False        False         False
#
# [510005 rows x 892 columns]

# %% [markdown]
# # Building first model

# %%
# importing models
from sklearn.tree import DecisionTreeRegressor
# import mae
from sklearn.metrics import mean_absolute_error
# import db split to validate data
from sklearn.model_selection import train_test_split

# %%
# define model. Specify a number for random_state to ensure same results each run
car_model = DecisionTreeRegressor(random_state=1)

# fit model
car_model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
# predicting price
pred_car_price = car_model.predict(X)
# checking mae
mae_pred = mean_absolute_error(y,pred_car_price)
mae_pred
# Out:
# 0.30909500887246205

# %%
# % of the mean
mae_pred_proc = (mae_pred/y.mean())*100
mae_pred_proc
# Out:
# 0.0022624299536692224

# %% [markdown]
# **Observation: MAE is very low, only `0.309`, it represents just `0.002%` of the average car price.**

# %% [markdown]
# # Validating model

# %%
# building new model

# spliting data to train and validation
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# define new car model
car_model_with_validation = DecisionTreeRegressor(random_state = 1)
# fiting model 
car_model_with_validation.fit(train_X, train_y)
# predicting price
pred_car_price_with_validation = car_model_with_validation.predict(val_X)

# %%
# checking mae
mae_pred_with_validation = mean_absolute_error(val_y, pred_car_price_with_validation)
mae_pred_with_validation
# Out:
# 2003.383821430252

# %%
# % of the mean
mae_pred_with_validation_proc = (mae_pred_with_validation/y.mean())*100
mae_pred_with_validation_proc
# Out:
# 14.663826448813053

# %% [markdown]
# **Observation: MAE is much bigger than without validation `2003.38`, it represents just `14.66%` of the average car price.**

# %% [markdown]
# # Underfitting and Overfitting

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state = 1)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  4838
# Max leaf nodes: 50  		 Mean Absolute Error:  3726
# Max leaf nodes: 500  		 Mean Absolute Error:  2519
# Max leaf nodes: 5000  		 Mean Absolute Error:  1750

# %%
my_mae_proc = (my_mae  /y.mean())*100
my_mae_proc
# Out:
# 12.816139158053891

# %% [markdown]
# **Observation: From the `max_leaf_nodes = [5, 50, 500, 5000]`, the best MAE occurs when `max_leaf_nodes` is equal to `5000`, with a value of `1750`, representing just `12.82%`.**

# %% [markdown]
# # Creating random forest

# %%
# importing random forest
from sklearn.ensemble import RandomForestRegressor

# define random model
forest_model = RandomForestRegressor(random_state=1)
# fiting model
forest_model.fit(train_X, train_y)
# predicting 
car_price_forest_pred = forest_model.predict(val_X)
# compare car_price_forest_pred with val_y in mae
mae_random_forest = mean_absolute_error(val_y, car_price_forest_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 7
#       5 forest_model = RandomForestRegressor(random_state=1)
#       6 # fiting model
# ----> 7 forest_model.fit(train_X, train_y)
#       8 # predicting
#       9 car_price_forest_pred = forest_model.predict(val_X)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
# --> 473 trees = Parallel(
#     474     n_jobs=self.n_jobs,
#     475     verbose=self.verbose,
#     476     prefer="threads",
#     477 )(
#     478     delayed(_parallel_build_trees)(
#     479         t,
#     480         self.bootstrap,
#     481         X,
#     482         y,
#     483         sample_weight,
#     484         i,
#     485         len(trees),
#     486         verbose=self.verbose,
#     487         class_weight=self.class_weight,
#     488         n_samples_bootstrap=n_samples_bootstrap,
#     489     )
#     490     for i, t in enumerate(trees)
#     491 )
#     493 # Collect newly grown trees
#     494 self.estimators_.extend(trees)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:184, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     181     elif class_weight == "balanced_subsample":
#     182         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 184     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     185 else:
#     186     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/tree/_classes.py:1247, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1218 def fit(self, X, y, sample_weight=None, check_input=True):
#    1219     """Build a decision tree regressor from the training set (X, y).
#    1220
#    1221     Parameters
#    (...)
#    1244         Fitted estimator.
#    1245     """
# -> 1247     super().fit(
#    1248         X,
#    1249         y,
#    1250         sample_weight=sample_weight,
#    1251         check_input=check_input,
#    1252     )
#    1253     return self
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/tree/_classes.py:379, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     368 else:
#     369     builder = BestFirstTreeBuilder(
#     370         splitter,
#     371         min_samples_split,
#    (...)
#     376         self.min_impurity_decrease,
#     377     )
# --> 379 builder.build(self.tree_, X, y, sample_weight)
#     381 if self.n_outputs_ == 1 and is_classifier(self):
#     382     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
mae_random_forest_proc = (mae_random_forest/y.mean())*100
mae_random_forest_proc

# %% [markdown]
# **Observation: RandomForestRegressor have the best from previous method MAE equal `1515`,representing just `11.1%`.**

# %% [markdown]
# # Create Linear Regression

# %%
# importing Linear Regression
from sklearn.linear_model import LinearRegression

# creating Linear Regression model
linear_regression_model = LinearRegression()

# fiting model
linear_regression_model.fit(train_X, train_y)

# predicting price
pred_price_linear_regression = linear_regression_model.predict(val_X)

# compare car_price_forest_pred with val_y in mae
mae_linear_regression = mean_absolute_error(val_y, pred_price_linear_regression)
mae_linear_regression
# Out:
# 2615.091969767928

# %%
mae_linear_regression_proc = (mae_linear_regression/y.mean())*100
mae_linear_regression_proc
# Out:
# 19.141242123531157

# %%
comparision_table = pd.DataFrame([
    ['MAE', mae_pred, mae_pred_with_validation, my_mae,mae_random_forest],
    ['MAE of mean %', mae_pred, mae_pred_with_validation_proc, my_mae_proc, mae_random_forest_proc]
], columns = ['','Full fill','Validadion','5000 leaf','Random Forest'])
comparision_table
